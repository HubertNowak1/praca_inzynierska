# %% [markdown]
# # Regresja liniowa

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.regression.quantile_regression import QuantReg

# %%
clean_data = pd.read_csv("clean_data.csv", encoding="latin1")

clean_data = clean_data.rename(columns={
    "ï»¿Kraj": "Kraj"
})

# %%
clean_data.head()
# Out:
#       Kraj   Rok  Stopa_bezrobocia  Edukacja  Dlugosc_zycia   Zdrowie  \
# 0  Albania  1996            13.928   3.08351         74.113       NaN
# 1  Albania  2002            17.891   3.11780         75.299  5.664645
# 2  Albania  2005            15.966   3.28155         76.427  5.729545
# 3  Albania  2008            13.060       NaN         78.248  5.509003
# 4  Albania  2012            13.376   3.29534         78.084  6.157462
#
#     Inflacja  Gini  Wspolczynnik_urbanizacji  Skolaryzacja  Rolnictwo  \
# 0  12.725478  27.0                 38.899604           NaN  33.561661
# 1   7.770526  31.7                 43.152042    110.338921  19.763916
# 2   2.366582  30.6                 45.993767    107.016144  17.124718
# 3   3.320871  30.0                 49.385070    100.383003  15.422100
# 4   2.031593  29.0                 53.863755    102.067361  17.591369
#
#    Dzieci_0-14   p0p50  p90p100  p99p100      PKB_pc  Indeks_nierow Kontynent
# 0    31.123281  0.1883   0.3256   0.0814   6741.8751       0.432289    Europe
# 1    28.284316  0.1803   0.3362   0.0862   9001.8889       0.478092    Europe
# 2    25.870379  0.1846   0.3311   0.0842  10336.2767       0.456121    Europe
# 3    23.363673  0.1860   0.3306   0.0857  12396.2443       0.460753    Europe
# 4    20.292086  0.1903   0.3301   0.0855  13472.0161       0.449291    Europe

# %%
clean_data['Gini'] = clean_data['Gini']/100

# %%
# Logarytm PKB per capita (standard w literaturze)
clean_data['ln_pkb_pc'] = np.log(clean_data['PKB_pc'])
# Wybór zmiennych do modelu
vars_model = [
    'Kraj',
    'Indeks_nierow',
    'Gini',
    'Zdrowie',
    'Edukacja',
    'Stopa_bezrobocia',
    'Dlugosc_zycia',
    'Inflacja',
    'ln_pkb_pc',
    'Wspolczynnik_urbanizacji',
    'Skolaryzacja',
    'Rolnictwo',
    'Dzieci_0-14'
]

# Usunięcie obserwacji z brakami danych
data_model = clean_data[vars_model].dropna()

# %%
Y = data_model['Gini']

X = data_model[
    [
    'Zdrowie',
    'Edukacja',
    'Stopa_bezrobocia',
    'Dlugosc_zycia',
    'Inflacja',
    'ln_pkb_pc',
    'Wspolczynnik_urbanizacji',
    'Skolaryzacja',
    'Rolnictwo',
    'Dzieci_0-14'
    ]
]

# Dodanie wyrazu wolnego
X = sm.add_constant(X)
ols_model = sm.OLS(Y, X).fit()
print(ols_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Gini   R-squared:                       0.547
# Model:                            OLS   Adj. R-squared:                  0.543
# Method:                 Least Squares   F-statistic:                     149.3
# Date:                Sun, 04 Jan 2026   Prob (F-statistic):          1.17e-204
# Time:                        20:08:06   Log-Likelihood:                 1888.3
# No. Observations:                1249   AIC:                            -3755.
# Df Residuals:                    1238   BIC:                            -3698.
# Df Model:                          10
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        0.5116      0.056      9.158      0.000       0.402       0.621
# Zdrowie                      0.0003      0.001      0.304      0.761      -0.001       0.002
# Edukacja                    -0.0075      0.001     -6.326      0.000      -0.010      -0.005
# Stopa_bezrobocia             0.0020      0.000      5.409      0.000       0.001       0.003
# Dlugosc_zycia                0.0006      0.000      1.327      0.185      -0.000       0.002
# Inflacja                    -0.0002      0.000     -1.464      0.144      -0.001    8.16e-05
# ln_pkb_pc                   -0.0531      0.005    -10.275      0.000      -0.063      -0.043
# Wspolczynnik_urbanizacji     0.0013      0.000      9.291      0.000       0.001       0.002
# Skolaryzacja                 0.0016      0.000      8.959      0.000       0.001       0.002
# Rolnictwo                   -0.0070      0.000    -15.195      0.000      -0.008      -0.006
# Dzieci_0-14                  0.0070      0.000     22.896      0.000       0.006       0.008
# ==============================================================================
# Omnibus:                       11.427   Durbin-Watson:                   0.490
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               11.484
# Skew:                           0.220   Prob(JB):                      0.00321
# Kurtosis:                       3.165   Cond. No.                     5.40e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.4e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
Y = data_model['Indeks_nierow']

X = data_model[
    [
    'Zdrowie',
    'Edukacja',
    'Stopa_bezrobocia',
    'Dlugosc_zycia',
    'Inflacja',
    'ln_pkb_pc',
    'Wspolczynnik_urbanizacji',
    'Skolaryzacja',
    'Rolnictwo',
    'Dzieci_0-14'
    ]
]

# Dodanie wyrazu wolnego
X = sm.add_constant(X)
ols_model = sm.OLS(Y, X).fit()
print(ols_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Indeks_nierow   R-squared:                       0.471
# Model:                            OLS   Adj. R-squared:                  0.467
# Method:                 Least Squares   F-statistic:                     110.3
# Date:                Sun, 04 Jan 2026   Prob (F-statistic):          1.75e-163
# Time:                        20:08:06   Log-Likelihood:                -1304.3
# No. Observations:                1249   AIC:                             2631.
# Df Residuals:                    1238   BIC:                             2687.
# Df Model:                          10
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        5.2511      0.720      7.294      0.000       3.839       6.663
# Zdrowie                     -0.0343      0.011     -3.217      0.001      -0.055      -0.013
# Edukacja                    -0.0707      0.015     -4.637      0.000      -0.101      -0.041
# Stopa_bezrobocia            -0.0086      0.005     -1.778      0.076      -0.018       0.001
# Dlugosc_zycia                0.0193      0.006      3.099      0.002       0.007       0.032
# Inflacja                    -0.0036      0.002     -1.719      0.086      -0.008       0.001
# ln_pkb_pc                   -0.8961      0.067    -13.454      0.000      -1.027      -0.765
# Wspolczynnik_urbanizacji     0.0208      0.002     11.659      0.000       0.017       0.024
# Skolaryzacja                 0.0188      0.002      8.309      0.000       0.014       0.023
# Rolnictwo                   -0.0904      0.006    -15.285      0.000      -0.102      -0.079
# Dzieci_0-14                  0.0640      0.004     16.303      0.000       0.056       0.072
# ==============================================================================
# Omnibus:                      490.207   Durbin-Watson:                   0.490
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2870.665
# Skew:                           1.717   Prob(JB):                         0.00
# Kurtosis:                       9.586   Cond. No.                     5.40e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.4e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
country_pkb = (
    clean_data
    .groupby('Kraj')['PKB_pc']
    .mean()
    .reset_index()
)

country_pkb['tercyl_pkb'] = pd.qcut(
    country_pkb['PKB_pc'],
    q=3,
    labels=['niski', 'średni', 'wysoki']
)

# %%
data_model = data_model.merge(
    country_pkb[['Kraj', 'tercyl_pkb']],
    on='Kraj',
    how='left'
)

# %%
for tercyl in ['niski', 'średni', 'wysoki']:
    subset = data_model[data_model['tercyl_pkb'] == tercyl]

    Y = subset['Gini']
    X = subset[
        [
            'Zdrowie',
            'Edukacja',
            'Stopa_bezrobocia',
            'Dlugosc_zycia',
            'Inflacja',
            'ln_pkb_pc',
            'Wspolczynnik_urbanizacji',
            'Skolaryzacja',
            'Rolnictwo',
            'Dzieci_0-14'
        ]
    ]

    X = sm.add_constant(X)
    model = sm.OLS(Y, X).fit()

    print(f"\n===== Tercyl PKB: {tercyl.upper()} =====")
    print(model.summary())
# Out:
# ===== Tercyl PKB: NISKI =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Gini   R-squared:                       0.422
# Model:                            OLS   Adj. R-squared:                  0.371
# Method:                 Least Squares   F-statistic:                     8.322
# Date:                Sun, 04 Jan 2026   Prob (F-statistic):           4.93e-10
# Time:                        20:09:25   Log-Likelihood:                 193.86
# No. Observations:                 125   AIC:                            -365.7
# Df Residuals:                     114   BIC:                            -334.6
# Df Model:                          10
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        0.0393      0.234      0.168      0.867      -0.425       0.504
# Zdrowie                      0.0055      0.003      1.721      0.088      -0.001       0.012
# Edukacja                     0.0058      0.003      1.801      0.074      -0.001       0.012
# Stopa_bezrobocia             0.0018      0.002      1.070      0.287      -0.002       0.005
# Dlugosc_zycia               -0.0007      0.001     -0.506      0.614      -0.003       0.002
# Inflacja                    -0.0007      0.001     -0.750      0.455      -0.003       0.001
# ln_pkb_pc                    0.0003      0.019      0.015      0.988      -0.037       0.038
# Wspolczynnik_urbanizacji     0.0009      0.000      1.864      0.065   -5.56e-05       0.002
# Skolaryzacja                 0.0008      0.000      3.127      0.002       0.000       0.001
# Rolnictwo                   -0.0027      0.001     -3.329      0.001      -0.004      -0.001
# Dzieci_0-14                  0.0069      0.002      4.185      0.000       0.004       0.010
# ==============================================================================
# Omnibus:                        9.815   Durbin-Watson:                   1.406
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):               19.187
# Skew:                          -0.238   Prob(JB):                     6.82e-05
# Kurtosis:                       4.859   Cond. No.                     6.48e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.48e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ===== Tercyl PKB: ŚREDNI =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Gini   R-squared:                       0.663
# Model:                            OLS   Adj. R-squared:                  0.654
# Method:                 Least Squares   F-statistic:                     72.76
# Date:                Sun, 04 Jan 2026   Prob (F-statistic):           4.31e-81
# Time:                        20:09:25   Log-Likelihood:                 577.96
# No. Observations:                 381   AIC:                            -1134.
# Df Residuals:                     370   BIC:                            -1091.
# Df Model:                          10
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       -0.6417      0.138     -4.639      0.000      -0.914      -0.370
# Zdrowie                      0.0064      0.002      3.611      0.000       0.003       0.010
# Edukacja                     0.0012      0.002      0.633      0.527      -0.003       0.005
# Stopa_bezrobocia             0.0017      0.001      2.802      0.005       0.001       0.003
# Dlugosc_zycia                0.0023      0.001      2.656      0.008       0.001       0.004
# Inflacja                    -0.0002      0.000     -1.243      0.215      -0.001       0.000
# ln_pkb_pc                    0.0387      0.014      2.698      0.007       0.010       0.067
# Wspolczynnik_urbanizacji    -0.0003      0.000     -1.129      0.260      -0.001       0.000
# Skolaryzacja                 0.0029      0.000      7.796      0.000       0.002       0.004
# Rolnictwo                   -0.0071      0.001     -7.815      0.000      -0.009      -0.005
# Dzieci_0-14                  0.0092      0.001     18.016      0.000       0.008       0.010
# ==============================================================================
# Omnibus:                        4.528   Durbin-Watson:                   0.772
# Prob(Omnibus):                  0.104   Jarque-Bera (JB):                5.168
# Skew:                          -0.121   Prob(JB):                       0.0755
# Kurtosis:                       3.517   Cond. No.                     7.31e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.31e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ===== Tercyl PKB: WYSOKI =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Gini   R-squared:                       0.557
# Model:                            OLS   Adj. R-squared:                  0.551
# Method:                 Least Squares   F-statistic:                     92.07
# Date:                Sun, 04 Jan 2026   Prob (F-statistic):          2.67e-122
# Time:                        20:09:25   Log-Likelihood:                 1330.8
# No. Observations:                 743   AIC:                            -2640.
# Df Residuals:                     732   BIC:                            -2589.
# Df Model:                          10
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        0.6861      0.079      8.708      0.000       0.531       0.841
# Zdrowie                      0.0041      0.001      4.201      0.000       0.002       0.006
# Edukacja                    -0.0186      0.001    -12.983      0.000      -0.021      -0.016
# Stopa_bezrobocia             0.0009      0.000      1.973      0.049    4.49e-06       0.002
# Dlugosc_zycia                0.0002      0.001      0.361      0.718      -0.001       0.002
# Inflacja                    -0.0005      0.000     -1.840      0.066      -0.001    3.32e-05
# ln_pkb_pc                   -0.0588      0.007     -8.918      0.000      -0.072      -0.046
# Wspolczynnik_urbanizacji     0.0013      0.000      8.604      0.000       0.001       0.002
# Skolaryzacja                 0.0009      0.000      2.452      0.014       0.000       0.002
# Rolnictwo                   -0.0020      0.001     -1.744      0.082      -0.004       0.000
# Dzieci_0-14                  0.0074      0.000     18.477      0.000       0.007       0.008
# ==============================================================================
# Omnibus:                       13.048   Durbin-Watson:                   0.302
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               13.487
# Skew:                          -0.291   Prob(JB):                      0.00118
# Kurtosis:                       3.310   Cond. No.                     7.94e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.94e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
for tercyl in ['niski', 'średni', 'wysoki']:
    subset = data_model[data_model['tercyl_pkb'] == tercyl]

    Y = subset['Indeks_nierow']
    X = subset[
        [
            'Zdrowie',
            'Edukacja',
            'Stopa_bezrobocia',
            'Dlugosc_zycia',
            'Inflacja',
            'ln_pkb_pc',
            'Wspolczynnik_urbanizacji',
            'Skolaryzacja',
            'Rolnictwo',
            'Dzieci_0-14'
        ]
    ]

    X = sm.add_constant(X)
    model = sm.OLS(Y, X).fit()

    print(f"\n===== Tercyl PKB: {tercyl.upper()} =====")
    print(model.summary())
# Out:
# ===== Tercyl PKB: NISKI =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Indeks_nierow   R-squared:                       0.280
# Model:                            OLS   Adj. R-squared:                  0.217
# Method:                 Least Squares   F-statistic:                     4.438
# Date:                Sun, 04 Jan 2026   Prob (F-statistic):           2.81e-05
# Time:                        20:17:31   Log-Likelihood:                -83.417
# No. Observations:                 125   AIC:                             188.8
# Df Residuals:                     114   BIC:                             219.9
# Df Model:                          10
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       -1.9915      2.155     -0.924      0.357      -6.261       2.278
# Zdrowie                      0.0510      0.030      1.724      0.087      -0.008       0.110
# Edukacja                     0.0321      0.030      1.078      0.283      -0.027       0.091
# Stopa_bezrobocia             0.0095      0.016      0.614      0.540      -0.021       0.040
# Dlugosc_zycia                0.0160      0.012      1.333      0.185      -0.008       0.040
# Inflacja                     0.0047      0.009      0.532      0.596      -0.013       0.022
# ln_pkb_pc                    0.0490      0.174      0.283      0.778      -0.295       0.393
# Wspolczynnik_urbanizacji    -0.0013      0.004     -0.287      0.775      -0.010       0.007
# Skolaryzacja                 0.0051      0.002      2.166      0.032       0.000       0.010
# Rolnictwo                   -0.0259      0.007     -3.485      0.001      -0.041      -0.011
# Dzieci_0-14                  0.0355      0.015      2.332      0.021       0.005       0.066
# ==============================================================================
# Omnibus:                       24.005   Durbin-Watson:                   1.200
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.020
# Skew:                           0.803   Prob(JB):                     3.74e-11
# Kurtosis:                       5.577   Cond. No.                     6.48e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.48e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ===== Tercyl PKB: ŚREDNI =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Indeks_nierow   R-squared:                       0.578
# Model:                            OLS   Adj. R-squared:                  0.566
# Method:                 Least Squares   F-statistic:                     50.58
# Date:                Sun, 04 Jan 2026   Prob (F-statistic):           3.48e-63
# Time:                        20:17:31   Log-Likelihood:                -396.00
# No. Observations:                 381   AIC:                             814.0
# Df Residuals:                     370   BIC:                             857.4
# Df Model:                          10
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       -6.1928      1.783     -3.474      0.001      -9.698      -2.687
# Zdrowie                      0.0384      0.023      1.691      0.092      -0.006       0.083
# Edukacja                    -0.0107      0.025     -0.434      0.664      -0.059       0.038
# Stopa_bezrobocia            -0.0130      0.008     -1.631      0.104      -0.029       0.003
# Dlugosc_zycia                0.0291      0.011      2.637      0.009       0.007       0.051
# Inflacja                    -0.0066      0.003     -2.565      0.011      -0.012      -0.002
# ln_pkb_pc                   -0.0317      0.185     -0.172      0.864      -0.395       0.331
# Wspolczynnik_urbanizacji     0.0159      0.004      4.465      0.000       0.009       0.023
# Skolaryzacja                 0.0383      0.005      7.960      0.000       0.029       0.048
# Rolnictwo                   -0.0791      0.012     -6.726      0.000      -0.102      -0.056
# Dzieci_0-14                  0.0717      0.007     10.946      0.000       0.059       0.085
# ==============================================================================
# Omnibus:                      103.914   Durbin-Watson:                   0.872
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              340.547
# Skew:                           1.213   Prob(JB):                     1.12e-74
# Kurtosis:                       6.946   Cond. No.                     7.31e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.31e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# ===== Tercyl PKB: WYSOKI =====
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Indeks_nierow   R-squared:                       0.473
# Model:                            OLS   Adj. R-squared:                  0.466
# Method:                 Least Squares   F-statistic:                     65.82
# Date:                Sun, 04 Jan 2026   Prob (F-statistic):           4.39e-95
# Time:                        20:17:31   Log-Likelihood:                -615.71
# No. Observations:                 743   AIC:                             1253.
# Df Residuals:                     732   BIC:                             1304.
# Df Model:                          10
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        8.7246      1.082      8.064      0.000       6.601      10.848
# Zdrowie                      0.0238      0.013      1.778      0.076      -0.002       0.050
# Edukacja                    -0.1491      0.020     -7.575      0.000      -0.188      -0.110
# Stopa_bezrobocia            -0.0251      0.006     -4.072      0.000      -0.037      -0.013
# Dlugosc_zycia               -0.0129      0.009     -1.429      0.153      -0.031       0.005
# Inflacja                    -0.0043      0.004     -1.151      0.250      -0.012       0.003
# ln_pkb_pc                   -0.9012      0.091     -9.949      0.000      -1.079      -0.723
# Wspolczynnik_urbanizacji     0.0158      0.002      7.725      0.000       0.012       0.020
# Skolaryzacja                 0.0084      0.005      1.722      0.086      -0.001       0.018
# Rolnictwo                   -0.0996      0.016     -6.274      0.000      -0.131      -0.068
# Dzieci_0-14                  0.0938      0.005     17.102      0.000       0.083       0.105
# ==============================================================================
# Omnibus:                      553.008   Durbin-Watson:                   0.301
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9991.251
# Skew:                           3.206   Prob(JB):                         0.00
# Kurtosis:                      19.781   Cond. No.                     7.94e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.94e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
